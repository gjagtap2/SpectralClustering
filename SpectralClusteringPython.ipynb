# %%
import pandas as pd
import numpy as np

# %%
from sklearn.feature_extraction import image

# %%
import numpy as np
import matplotlib.pyplot as plt
import ipympl
import imageio as iio
import skimage

# %%
import skimage                 # form 1, load whole skimage library
import skimage.draw            # form 2, load skimage.draw module only
from skimage.draw import disk  # form 3, load only the disk function
import numpy as np             # form 4, load all of numpy into an object called np

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.image import img_to_graph
from sklearn.cluster import spectral_clustering
from sklearn.datasets import load_digits

# %%
# importing required libraries
import matplotlib.pyplot as plt
import matplotlib.image as img
  
# reading the image
testImage = img.imread('yellow.jpg')
  
# displaying the image
plt.imshow(testImage)

# %%
import numpy as np

# %%
graph = testImage.img_to_graph(img, mask=mask)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [4], in <cell line: 1>()
# ----> 1 graph = testImage.img_to_graph(img, mask=mask)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'img_to_graph'

# %%
mask = testImage.astype(bool)

# %%
from sklearn.feature_extraction import image

graph = image.img_to_graph(testImage, mask=mask)

# %%
graph.data = np.exp(-graph.data / graph.data.std())

# %%
from sklearn.cluster import spectral_clustering
import matplotlib.pyplot as plt

labels = spectral_clustering(graph, n_clusters=4, eigen_solver="arpack")
label_im = np.full(mask.shape, -1.0)
label_im[mask] = labels

fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(10, 5))
axs[0].matshow(testImage)
axs[1].matshow(label_im)

plt.show()
